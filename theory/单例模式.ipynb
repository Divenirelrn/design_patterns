# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# 单例模式的内存释放问题：<br/>
# 单例模式一般只有一个对象，不会占用多大内存；在程序结束后，会自动释放。因此，一般不考虑单例模式的内存释放问题。

# %% [markdown]
# 多线程：
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)
